# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading of data set

# %%
sales = pd.read_csv('supermarket_sales - Sheet1.csv')

# %%
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
sales.count()
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
sales.size
# Out:
# 17000

# %%
sales.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sales.shape
# Out:
# (1000, 17)

# %% [markdown]
# # Dropping the unused columns

# %%
sales = pd.read_csv('supermarket_sales - Sheet1.csv').drop(['Invoice ID', 'Customer type', 'Date', 'Time'], axis = 1)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   object
#  1   City                     1000 non-null   object
#  2   Gender                   1000 non-null   object
#  3   Product line             1000 non-null   object
#  4   Unit price               1000 non-null   float64
#  5   Quantity                 1000 non-null   int64
#  6   Tax 5%                   1000 non-null   float64
#  7   Total                    1000 non-null   float64
#  8   Payment                  1000 non-null   object
#  9   cogs                     1000 non-null   float64
#  10  gross margin percentage  1000 non-null   float64
#  11  gross income             1000 non-null   float64
#  12  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(5)
# ...

# %%
sales
# Out:
#     Branch       City  Gender            Product line  Unit price  Quantity  \
# 0        A     Yangon  Female       Health and beauty       74.69         7
# 1        C  Naypyitaw  Female  Electronic accessories       15.28         5
# 2        A     Yangon    Male      Home and lifestyle       46.33         7
# 3        A     Yangon    Male       Health and beauty       58.22         8
# 4        A     Yangon    Male       Sports and travel       86.31         7
# ..     ...        ...     ...                     ...         ...       ...
# 995      C  Naypyitaw    Male       Health and beauty       40.35         1
# 996      B   Mandalay  Female      Home and lifestyle       97.38        10
# 997      A     Yangon    Male      Food and beverages       31.84         1
# 998      A     Yangon    Male      Home and lifestyle       65.82         1
# 999      A     Yangon  Female     Fashion accessories       88.34         7
#
# ...

# %%
sales[['Gender', 'Payment']] = sales[['Gender', 'Payment']].apply(lambda col:pd.Categorical(col).codes)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   object
#  1   City                     1000 non-null   object
#  2   Gender                   1000 non-null   int8
#  3   Product line             1000 non-null   object
#  4   Unit price               1000 non-null   float64
#  5   Quantity                 1000 non-null   int64
#  6   Tax 5%                   1000 non-null   float64
#  7   Total                    1000 non-null   float64
#  8   Payment                  1000 non-null   int8
#  9   cogs                     1000 non-null   float64
#  10  gross margin percentage  1000 non-null   float64
#  11  gross income             1000 non-null   float64
#  12  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), int8(2), object(3)
# ...

# %% [markdown]
# # Histogram

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sales.hist(bins = 60, figsize = (20, 12))
plt.show()

# %%
sales.describe()
# Out:
#             Gender   Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.499000    55.672130     5.510000    15.379369   322.966749
# std       0.500249    26.494628     2.923431    11.708825   245.885335
# min       0.000000    10.080000     1.000000     0.508500    10.678500
# 25%       0.000000    32.875000     3.000000     5.924875   124.422375
# 50%       0.000000    55.230000     5.000000    12.088000   253.848000
# 75%       1.000000    77.935000     8.000000    22.445250   471.350250
# max       1.000000    99.960000    10.000000    49.650000  1042.650000
#
#            Payment        cogs  gross margin percentage  gross income  \
# count  1000.000000  1000.00000             1.000000e+03   1000.000000
# mean      1.001000   307.58738             4.761905e+00     15.379369
# std       0.830475   234.17651             6.131498e-14     11.708825
# ...

# %%
sales[['Unit price', 'Quantity', 'Total', 'gross income']].hist(bins = 50, figsize = (20, 15))
plt.show()

# %% [markdown]
# # Pie chart

# %%
plt.figure(figsize=(16,9))
sales['Rating'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Rating'>

# %% [markdown]
# # Vizualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(18,9))
sns.heatmap(sales.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# # Initiating Machine Learning

# %%
from sklearn.model_selection import train_test_split

# %%
X = sales.drop(['Branch', 'City', 'Product line', 'Rating'], axis=1)
y = sales['Rating'] 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=20)

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

def cross_val(model):
    pred = cross_val_score(model, X, y, cv=10)
    return pred.mean()

def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2_Square', r2_square)
    
    
def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('stdscalar', StandardScaler())
])

X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression(normalize=True)
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
print(lin_reg.intercept_)
# Out:
# 6.999750000000001

# %%
coeff_sales = pd.DataFrame(lin_reg.coef_, X.columns, columns=['Coefficient'])
coeff_sales
# Out:
#                          Coefficient
# Gender                      0.037410
# Unit price                  0.123985
# Quantity                    0.038007
# Tax 5%                     -0.047227
# Total                      -0.047227
# Payment                    -0.003816
# cogs                       -0.047227
# gross margin percentage     0.000000
# gross income               -0.047227

# %%
pred = lin_reg.predict(X_test)

# %%
pred
# Out:
# array([7.00260446, 6.86547467, 7.32389655, 7.10105031, 7.02692029,
#        6.98971872, 7.17221579, 6.91372425, 6.9855163 , 7.02434995,
#        6.94912901, 6.82592161, 7.01982706, 7.07105395, 6.89643761,
#        7.00942445, 7.07167466, 7.06982928, 6.93518663, 6.85002851,
#        7.01693106, 7.05674693, 6.78182183, 7.01977665, 7.02325431,
#        7.03714488, 7.02886987, 6.98929535, 6.98336191, 7.13020961,
#        6.98761971, 6.88403878, 7.06498748, 6.88352211, 6.89936455,
#        7.11645358, 6.7738025 , 7.20283019, 6.88383624, 7.00221412,
#        7.1860961 , 6.80863656, 6.67417324, 6.94662602, 7.30042035,
#        7.05601073, 6.93005203, 7.07900779, 6.94330838, 6.92900273,
#        7.10125988, 6.88519985, 6.88431872, 6.77057022, 7.00776664,
#        6.95256252, 7.02037491, 6.98849387, 6.96406353, 6.91538923,
#        6.88415521, 7.17546358, 6.96852103, 6.94155093, 7.15703473,
#        6.94508306, 7.1169968 , 6.82511407, 7.17719737, 6.98256464,
# ...

# %%
test_pred = lin_reg.predict(X_test)
train_pred = lin_reg.predict(X_train)

print('Test data evaluation:\n')
print_evaluate(y_test, test_pred)
print('Train data evaluation:\n')
print_evaluate(y_train, train_pred)

results_df = pd.DataFrame(data=[["Linear Regression", *evaluate(y_test, test_pred) , cross_val(LinearRegression())]], 
                          columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
# Out:
# Test data evaluation:
#
# MAE: 1.543800583967857
# MSE: 3.1857407365164505
# RMSE: 1.7848643468108298
# R2_Square -0.018430093483235543
# Train data evaluation:
#
# MAE: 1.4636618219800974
# MSE: 2.887935345628294
# RMSE: 1.69939264021835
# R2_Square 0.005026517320561696
